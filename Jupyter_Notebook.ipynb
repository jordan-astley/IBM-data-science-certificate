# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on Watson Studio

# %% [markdown]
# Jordan Astley
#
# Electrical Engineer

# %% [markdown]
# *I am interested in data science because I am passionate about engineering and technology. I think that data science will aid me highly in my career as it can be applied to many different fields to optimise the way we work and help make better descisions. It also allows us to reveal more information from  data which could help lead to more technological developments.*

# %% [markdown]
# ### The code in cell 5 finds the cube of the variable 'number'.

# %%
# finds the cube of the variable x
number = 8
print(f"The cube of {str(number)} = {str(number*number*number)}")
# Out:
# The cube of 8 = 512

# %% [markdown]
# - bullet 1
# - bullet 2
# - bullet 3
#
# ![cute-doggy.jpg](attachment:cute-doggy.jpg)
#
# ~This is an example of strikethrough~
